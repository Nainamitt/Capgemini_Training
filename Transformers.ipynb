# %%
from huggingface_hub import login
from dotenv import load_dotenv
import os

load_dotenv()

token = os.getenv("HUGGINGFACE_API_KEY")

# %%
#  Scenario: AI‑Powered Email Assistant
# You’re building an email drafting assistant for a corporate team.
# - When a user starts typing:
# “Artificial Intelligence will…”
# - The assistant uses GPT‑2 to auto‑complete the sentence with a coherent continuation.
# - Example output:
# “Artificial Intelligence will transform the way businesses interact with customers,
# enabling faster decisions and personalized experiences.”

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2" , token = token)

print(generator("Artificial Intelligence will", max_length=30))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Artificial Intelligence will be the first and only field that is made with the highest efficiency.\n\n"The goal of AI will be to be able to better interact with the world and find ways to make people better," said Bienenfeld. "But the challenges we face are very real. We\'re going to need to have deep understanding of the mechanisms and processes involved in the world to make it better."\n\nAnd it is not just humans who will be affected. The field will also need to recognize the importance of the human experience, he said. "In a smart world, it\'s very important to remember, \'it\'s important to do something that\'s human, not just for the humans.\'"\n\nThe next step for AI is in creating intelligent robots, said Bienenfeld. "The problem with AI is, we\'ve done a whole lot of research on how to make robots that are a little more human-like. The way we do that is we have to understand what makes human-like, and we\'ve found that robots that are more human-like are the ones that have the most control over the human body."\n\nWith that said, many of the scientists who have worked on AI have had a hard time figuring out how to make the AI work'}]

# %%
#  Scenario: Game Storyline Generator
# You’re designing a fantasy role‑playing game and need quick ideas for quests and dialogue.
# - The developer types a prompt:
# “The hero enters the ancient forest and discovers…”
# - The GPT‑2 pipeline continues the story:
# “The hero enters the ancient forest and discovers a hidden village where the people whisper of
#  a cursed artifact buried beneath the old ruins.”

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2" , token = token)

prompt = "The hero enters the ancient forest and discovers"

result = generator(prompt, max_length=50, num_return_sequences=1)

print(result[0]['generated_text'])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Passing `generation_config` together with generation-related arguments=({'num_return_sequences', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The hero enters the ancient forest and discovers a giant demon who is a little bit bigger than he was before. He is a giant monster with a giant body with his head cut off, and he has a strange, red eyes with a long sword with a golden spike.
#
# He has no eyes or tail, but he is able to see in the darkness.
#
# The hero has a vision of a great tree, and he is able to see in the darkness that there is a great tree behind him. The hero is able to see the great tree and the tree turns into a huge demon. The hero is able to see the trees and see the demon with his sword.
#
# The hero is a giant demon with a giant head cut off.
#
# The hero is an evil god with a red beard and an orange hair. The hero is a giant demon with a red head cut off.
#
# The hero's eyes are white with a purple color. The hero is a demon with a red beard and an orange hair.
#
# The hero is a demon with a red beard and a orange hair. The hero is a monster with a red beard and a red hair. The hero is a monster with a red beard and a red hair. The hero is a monster with a red beard and a

# %%
# Scenario: Research Assistant for Academic Papers
# Imagine you’re building a tool for university researchers who analyze large collections of academic papers.
# - A researcher uploads a sentence:
# “Deep learning models are powerful”
# - Your system uses the BERT tokenizer to break the sentence into smaller units (tokens).

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

text = "Deep learning models are powerful"

tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# ['deep', 'learning', 'models', 'are', 'powerful']

# %%
# 🏥 Scenario: Healthcare Chatbot for Patient Queries
# A hospital is developing a chatbot to help patients ask questions about their health.
# - A patient types:
# “Deep learning models are powerful” (or in practice, something like “I have chest pain and shortness of breath”).
# - The chatbot uses the BERT tokenizer to break the sentence into tokens:

# %%
from transformers import BertTokenizer

tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

text = "I have chest pain and shortness of breath"

tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['i', 'have', 'chest', 'pain', 'and', 'short', '##ness', 'of', 'breath']

# %%
# Scenario: Exploring Creativity in AI Writing
# A university professor is running a workshop on creative writing with AI.
# - The professor gives students the prompt:
# “The future of Artificial Intelligence”
# - The system uses GPT‑2 to generate continuations of the sentence.
# To demonstrate how temperature affects creativity:
# - With temperature = 0.2 (low randomness), the output is more predictable and conservative, e.g.:
# “The future of Artificial Intelligence will bring advancements in healthcare, education, and business.”

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2" , token = token)

prompt = "The future of Artificial Intelligence"

print(generator(prompt, max_length=40, temperature=0.2))
print(generator(prompt, max_length=40, temperature=0.8))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Passing `generation_config` together with generation-related arguments=({'temperature', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of Artificial Intelligence is uncertain.\n\nThe future of artificial intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe'}]
# [{'generated_text': 'The future of Artificial Intelligence is not clear, but it\'s certainly possible.\n\nFor a while now, Google has been making strides in its AI research and development. Last month, while working on AlphaGo, one researcher described AI as "the next big thing" and claimed it was aiming to "evolve from a concept to a system. We\'re still waiting on what the next big thing will look like."\n\nIt\'s not as though artificial intelligence has become as exciting as it used to be. Google recently admitted it has "quite a bit of experience" with deep learning software. The firm\'s founder, Sergey Brin, also said in a recent interview that "we are at a point in our career where we don\'t have a lot of experience in machine learning."\n\nI understand that Google\'s AI research is being done at the University of California, Berkeley, where a professor works on machine learning models. Google\'s first foray into deep learning is in its $5 billion DeepMind research project, which was led by Larry Page. The company has been able to build a series of self-driving cars, which had been touted as tech-enabled, which are now being tested on a large scale for other areas. But Google and others in the field have been very dismissive of'}]

# %%
#  Scenario: Scriptwriting Assistant for Film Production
# A film studio is experimenting with AI to help writers brainstorm dialogue and plot ideas.
# - The writer provides the prompt:
# “The future of Artificial Intelligence”
# - The system generates two versions of the continuation:
# - Temperature = 0.2 (low randomness)
# Output is more predictable and formal, e.g.:
# “The future of Artificial Intelligence will improve industries, enhance productivity, and reshape education.”
# → This is useful for serious, factual narration in a documentary script.
# - Temperature = 0.8 (higher randomness)
# Output is more imaginative and varied, e.g.:
# “The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.”
# → This is perfect for creative dialogue or speculative sci‑fi storytelling

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2" , token = token)

prompt = "The future of Artificial Intelligence"

# Low temperature
output1 = generator(prompt, max_length=30, temperature=0.2)

# High temperature
output2 = generator(prompt, max_length=30, temperature=0.8)

print("Low temperature:", output1[0]['generated_text'])
print("High temperature:", output2[0]['generated_text'])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Low temperature: The future of Artificial Intelligence is uncertain. The future of artificial intelligence is uncertain.
#
# The future of artificial intelligence is uncertain. The future of artificial intelligence is uncertain.
#
# The future of artificial intelligence is uncertain. The future of artificial intelligence is uncertain.
#
# The future of artificial intelligence is uncertain. The future of artificial intelligence is uncertain.
#
# The future of artificial intelligence is uncertain. The future of artificial intelligence is uncertain.
#
# The future of artificial intelligence is uncertain. The future of artificial intelligence is uncertain.
#
# The future of artificial intelligence is uncertain. The future of artificial intelligence is uncertain.
#
# The future of artificial intelligence is uncertain. The future of artificial intelligence is uncertain.
#
# The future of artificial intelligence is uncertain. The future of artificial intelligence is uncertain.
#
# The future of artificial intelligence is uncertain. The future of artificial intelligence is uncertain.
#
# The future of artificial intelligence is uncertain. The future of artificial intelligence is uncertain.
#
# The future of artificial intelligence is uncertain. The future of artificial intelligence is uncertain.
#
# The future of artificial intelligence is uncertain. The future of artificial intelligence is uncertain.
#
# The future of artificial intelligence is uncertain. The future of artificial intelligence is uncertain.
#
# The future of artificial intelligence is uncertain. The
# High temperature: The future of Artificial Intelligence
#
# In order to ensure that AI is ready for a major revolution, it will have to be able to do things that humans cannot. We already know that there are two potential strategies for building artificial intelligence, which are to develop AI that outperforms humans but is capable of producing interesting results in interesting situations and to improve the performance of people.
#
# In these scenarios, humans can take over the most important tasks of AI. They can replace humans who are now able to do tasks which humans would not be able to. These tasks are the tasks that humans need to do.
#
# These tasks can be done in the first place, by humans, in the most difficult and difficult situations (such as medical and medical research).
#
# It will be interesting to see how this future evolves. At least one new AI capability might be developed for medical research. This new AI system is called "mindless" AI, and will be an artificial intelligence capable of solving many of the most important and difficult tasks in medicine.
#
# As a result, it's very unlikely that this AI system will replace humans in medical research in the same amount as it does in artificial intelligence, which means that there will be many more people who are unable to do these tasks.
#
# In the

# %%
# Scenario: AI‑Powered News Headline Generator
# A digital media company wants to help journalists brainstorm headlines and opening lines for articles.
# - The system asks the journalist to enter a prompt (e.g., “Enter a prompt: The future of Artificial Intelligence”).
# - The GPT‑2 model then generates a continuation of the text, up to 50 tokens.
# - Example output:
# “The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge
#  our understanding of human potential.”

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2" , token = token)

prompt = input("Enter a prompt: ")

output = generator(prompt, max_length=50)

print(output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Enter a prompt:  The future of Artificial Intelligence
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The future of Artificial Intelligence and AI in the 21st century may depend upon how the technology is used and what the potential impact it has on society.
#
# Why should we care?
#
# The most important question for the future is, What are the next steps? If we want to develop AI, we need to learn to recognize, manage and control our own actions, and it is a great step in the right direction.
#
# This is a great question because it answers the question of what is the best way to manage our own lives. It also answers the question of what kind of AI should be used to drive change.
#
# The future of Artificial Intelligence and AI in the 21st century may depend on how the technology is used and what the potential impact it has on society.
#
# Will there be a single AI?
#
# A single AI is a single entity that can be programmed to do all kinds of things. It will be able to do all kinds of things. It will be able to do all kinds of things. It will be able to do all kinds of things.
#
# The AI that will be able to do all kinds of things will be a very small one. A small one would be a small machine, it would be able to do almost everything. So

# %%
# 🎓 Scenario: Student Brainstorming Tool for Essay Writing
# A college student is struggling to start their essay.
# - The system prompts them:
# “Enter a prompt:”
# - The student types:
# “The impact of technology on education”
# - The GPT‑2 model generates a continuation up to 50 tokens, for example:
# “The impact of technology on education has transformed classrooms, enabling online learning,
# personalized study plans, and global collaboration among students.”

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2" , token = token)

prompt = "The impact of technology on education"

result = generator(prompt, max_length=50)

print(result[0]['generated_text'])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The impact of technology on education has played a role in the decline of academic achievement in many countries, but the role of education in the nation's education system remains unclear.
#
# In a statement, the OECD said that "education is the major source of growth and employment for the country's youth and it is an important indicator of the extent to which the country's workforce is growing."
#
# "As the country's most high-tech technology sector continues to grow, it is important that the government not only focus on increasing education, but also investing in technology, which can help the economy grow faster and create jobs," the report said.
#
# The OECD's report found that between 2006 and 2010, the country's per capita income fell by 27.4 percent compared with a similar time period in 2011.
#
# Among OECD countries, education is the second-largest source of growth, followed by technology and trade, the OECD said.

# %%
# Scenario: AI Model Evaluation in a Startup
# A startup is building an AI‑powered content assistant to help marketers draft product descriptions.
# - The team wants to compare two models: GPT‑2 (larger, more expressive) and DistilGPT‑2 (smaller, faster, distilled version).
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# Longer, more detailed continuation, e.g.:
# “Artificial Intelligence will transform industries by automating processes, enhancing creativity, and
# reshaping how humans interact with technology.”
# → Richer but slower to run.
# - DistilGPT‑2 Output

# %%
from transformers import pipeline

gpt2 = pipeline("text-generation", model="gpt2" , token = token)
distilgpt2 = pipeline("text-generation", model="distilgpt2" , token = token)

prompt = "Artificial Intelligence will transform"

print("GPT2:", gpt2(prompt, max_length=40))
print("DistilGPT2:", distilgpt2(prompt, max_length=40))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2: [{'generated_text': "Artificial Intelligence will transform the way you think about the world that you live in. We'll help you understand the importance of the Internet and the importance of digital communication, and make sure that you are well-informed about your surroundings.\n\nWe're a global startup with a goal of solving the world's problems and creating a more secure and secure world. As a global business, we are committed to providing world-class technology and services. We know you want to be able to use our technology and services and offer you the services you need. We have an open and transparent service and we are committed to providing a secure, secure and secure world.\n\nHow can we help?\n\nIf you have questions or concerns, please contact us at: [email protected] or (404) 567-0444.\n\nThe Best of Silicon Valley is a national nonprofit organization dedicated to providing the best education in innovation. We are committed to building the best products and services for the world's people and to providing the best online services."}]
# DistilGPT2: [{'generated_text': 'Artificial Intelligence will transform the world of our lives.'}]

# %%
# Scenario: Educational Tool for Classroom Learning
# A high school teacher is introducing students to AI‑powered writing assistants.
# - The teacher wants to show how different models produce different styles of text.
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# More elaborate continuation, e.g.:
# “Artificial Intelligence will transform the way societies function, influencing education, healthcare, and the future of human creativity.”
# → Great for showing students how AI can generate rich, detailed ideas.
# - DistilGPT‑2 Output
# Shorter, faster continuation, e.g.:
# “Artificial Intelligence will transform our daily lives.”
# → Useful for demonstrating concise summaries.

# %%
from transformers import pipeline

# GPT-2 model
gpt2 = pipeline("text-generation", model="gpt2" , token = token)

# DistilGPT-2 model
distilgpt2 = pipeline("text-generation", model="distilgpt2" , token = token)

prompt = "Artificial Intelligence will transform"

print("GPT-2:", gpt2(prompt, max_length=40)[0]['generated_text'])
print("DistilGPT-2:", distilgpt2(prompt, max_length=40)[0]['generated_text'])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT-2: Artificial Intelligence will transform our world. Humans will become an integral part of our daily lives and will become the ultimate leader in the search for meaning and truth.
#
# The goal is to put an end to the belief that we live in a world of artificial intelligence and to create a world of compassion and change.
#
# The world will be a place of peace, safety and joy.
#
# The world will be a place of hope; a place of love; a place of truth; a place of truth.
#
# The world will be a place of peace and happiness.
#
# The world will be a place of love.
#
# The world will be a place of truth.
#
# The world will be a place of truth.
#
# The world will be a place of truth and love.
#
# The world will be a place of truth and happiness.
#
# The world will be a place of truth and love.
#
# The world will be a place of truth and happiness.
#
# The world will be a place of truth and love.
#
# The world will be a place of truth and happiness.
#
# The world will be a place of truth and happiness.
#
# The world will be a place of truth and love.
#
# The world will be a
# DistilGPT-2: Artificial Intelligence will transform our lives. It will transform the world. It will transform the world. It will transform the world. It will transform the world.
