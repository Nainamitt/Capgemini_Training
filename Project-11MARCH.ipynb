# %%
# Scenario-Based Assessment
# Case Study: AI Assistant for a University Helpdesk

# A large university receives thousands of student queries daily related to admissions, fees, hostel facilities, course
#  schedules, and exam results.

# Currently, these queries are answered manually by staff, causing:

# Slow response time
# High operational cost
# Inconsistent responses

# The university plans to develop an AI-powered chatbot using Generative AI and Large Language Models (LLMs) to
#  automatically respond to student questions.

# You are part of the AI consulting team tasked with designing the solution.

# ==========================================
# UNIVERSITY AI HELPDESK CHATBOT
# Demonstrates:
# Generative AI
# Large Language Models (LLMs)
# Tokenization
# Transformer Inference
# Prompt Engineering
# ==========================================

# Install required libraries first
# pip install transformers torch

# %%
# ==========================================
# UNIVERSITY AI HELPDESK CHATBOT
# ==========================================
# Demonstrates:
# - Generative AI
# - Large Language Models (LLMs)
# - Tokenization
# - Transformer Inference
# - Prompt Engineering
# ==========================================


from transformers import pipeline

knowledge_base = {
    "hostel": "Hostel admission requires an admission confirmation letter, government ID proof, and two passport-size photographs.",
    "registration": "Course registration happens online through the university portal before the semester deadline.",
    "fees": "Fees can be paid through the student dashboard using debit card, credit card, or net banking.",
    "exam": "Semester exams usually start in December and May.",
    "library": "Students must carry their university ID card to access the library."
}
generator = pipeline("text-generation", model="gpt2")


def get_kb_answer(question: str) -> str:
    """
    Checks if the question contains any keyword from the knowledge base.
    Returns the matched answer or None if not found.
    """
    question_lower = question.lower()
    for key, value in knowledge_base.items():
        if key in question_lower:
            return value
    return None


def generate_response(question: str) -> str:
    """
    Generates a natural language response using the generative AI model.
    Uses knowledge base answer as a fallback to provide context.
    """
    kb_answer = get_kb_answer(question)
    
    if kb_answer:
        prompt = f"Student Question: {question}\nAnswer: {kb_answer}"
    else:
        prompt = f"Student Question: {question}\nAnswer: Provide a polite, helpful response based on general university information."

    response = generator(prompt, max_new_tokens=60, temperature=0.6)
    final_answer = response[0]["generated_text"].split("Answer:")[-1].strip()
    return final_answer


if __name__ == "__main__":
    print("=== Welcome to the University AI Helpdesk ===")
    print("Type 'exit' to quit the chat.\n")
    
    while True:
        question = input("Ask your question: ").strip()
        if question.lower() in ["exit", "quit"]:
            print("Thank you for using the AI Helpdesk. Goodbye!")
            break
        
        answer = generate_response(question)
        print("\nAI Helpdesk Answer:")
        print(answer)
        print("-" * 50)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# === Welcome to the University AI Helpdesk ===
# Type 'exit' to quit the chat.
# Ask your question:  How can I apply for the hostel?
# Passing `generation_config` together with generation-related arguments=({'temperature', 'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=60) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# AI Helpdesk Answer:
# Hostel admission requires an admission confirmation letter, government ID proof, and two passport-size photographs.
# How Can I Apply for the Hostel?
# A. Apply online at www.hostel.com.
# B. Apply online at www.luther.com.
# C. Apply online at www.thevibe.com.
# D. Apply online at www.thev
# --------------------------------------------------
# Ask your question:  How do I register for my courses online?
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=60) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# AI Helpdesk Answer:
# Provide a polite, helpful response based on general university information.
# Students should be aware that they will need to provide their name, email address, and phone number.
# If they are unable to provide the correct information, they will be asked to provide a password.
# Students should also be aware that the Information Technology Manager (ITM) will be able to
# --------------------------------------------------
# Ask your question:  What is the deadline for course registration?
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=60) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# AI Helpdesk Answer:
# Course registration happens online through the university portal before the semester deadline.
# Course registration is open to all undergraduate and graduate students who are enrolled in the program. Course registration is not available for students who have completed all of the courses listed on the online application.
# Course registration is not available for students who have completed all of the courses listed on the online application. Course
# --------------------------------------------------
# Ask your question:  exit
# Thank you for using the AI Helpdesk. Goodbye!
